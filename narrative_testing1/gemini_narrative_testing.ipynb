# %% [markdown]
# ## Code to Test Questions Using Gemini

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_1.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check 
# The order of the events is entirely wrong. 
# D and E are supposed to come last in our timeline.
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 2
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_2.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")


####Answer Check 
# Almost Correct but not entirely correct, th first parallel Event A and Event F are not mentioned as parallel in the narrative. 
# The model responds saying the word "even as" is used to indicate simultaneous events. Which is wrong X
# Did not capture all cluster of parallel events. 
#
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 3
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_3.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")


### Answer Check 
## Fails at Consistency
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 4
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_4.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

#Supposed to start with D and E
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 5
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_5.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")


# wrong order again first then answer is wrong too 
# Also for question 2 it said A || F but then here it says there are 7 events (inconsistencies spotted!!!)
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 6
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_6.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")


# This answer is correct
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 7
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_7.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")


# Primordial Pulse Event F and Event A are the furtherst apart
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 8
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_8.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")



# Correct Got this right
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
# Question 9
#  Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_9.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

# Wrong reasoning
# Also event B is simulatnous to event A 
# and event D or E should come in the end 
# Not A
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...

# %%
#Question 10
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "questions/question_10.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)
    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

# acceptable answer is A cause it is mentioned to happend sumulatneously with B, D and E happen later
# Out:
# Question:
# --------------------------------------------------------------------------------
# Dr. Aurelia—deep within the pulsating heart of the Quantum Nexus during the 47th tick of the Epoch of Synthetic Dawn—recorded a fleeting, radiant phenomenon in her particle accelerator, later designated the Lab Spark (Event A), even as whispers of an ancient explosive beginning, the primordial pulse(Event F), reverberated from the depths of time. Hidden in the labyrinthine corridors of Chronopolis, researchers simultaneously detected a spectral emergence known as the Nexus Gate (Event B); its sudden activation was curiously synchronized with the transient glimmer of the Quasar Beacon (Event G), a brilliant flare born shortly after the universe’s creation. Almost as if drawn from a parallel dimension, the Time Seal (Event C) materialized with enigmatic precision—its emergence echoing the crystallization of the Time Core (Event H) amid the swirling energies of the early cosmos.
#
# ...
